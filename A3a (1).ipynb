# %%
pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/60.9 kB 1.4 MB/s eta 0:00:01
#      ---------------------------------------- 60.9/60.9 kB 1.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.2/11.5 MB 5.9 MB/s eta 0:00:02
#    -- ------------------------------------- 0.6/11.5 MB 7.5 MB/s eta 0:00:02
#    --- ------------------------------------ 1.1/11.5 MB 9.0 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.7/11.5 MB 9.0 MB/s eta 0:00:02
#    ------- -------------------------------- 2.2/11.5 MB 10.2 MB/s eta 0:00:01
#    -------- ------------------------------- 2.5/11.5 MB 10.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.4/11.5 MB 10.7 MB/s eta 0:00:01
#    ------------- -------------------------- 3.7/11.5 MB 10.4 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
data= pd.read_csv ("C:\\Users\\LENOVO\\Downloads\\Airline_customer_satisfaction.csv")

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib.pyplot
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# ...
#      ---------------------------------------- 0.0/165.5 kB ? eta -:--:--
#      -------------- ------------------------ 61.4/165.5 kB 3.2 MB/s eta 0:00:01
#      -------------------------------------- 165.5/165.5 kB 3.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------- ----- 256.0/294.9 kB 7.9 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 4.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.4/8.0 MB 13.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.1/8.0 MB 13.8 MB/s eta 0:00:01
#    ------ --------------------------------- 1.3/8.0 MB 14.1 MB/s eta 0:00:01
#    ------------ --------------------------- 2.5/8.0 MB 16.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.2/8.0 MB 14.7 MB/s eta 0:00:01
# ...

# %%
 pip install train_test_split from sklearn.model_selection
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement train_test_split (from versions: none)
# ERROR: No matching distribution found for train_test_split
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install logistic regression from sklearn.linear_model
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement logistic (from versions: none)
# ERROR: No matching distribution found for logistic
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
python.exe -m pip install --upgrade pip
# Out:
#   Cell In[17], line 1
#     python.exe -m pip install --upgrade pip
#                   ^
# SyntaxError: invalid syntax

# %%
python.exe -m pip install
# Out:
#   Cell In[18], line 1
#     python.exe -m pip install
#                   ^
# SyntaxError: invalid syntax

# %%
pip install logistic regression
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement logistic (from versions: none)
# ERROR: No matching distribution found for logistic
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      -------------------------------------- 60.8/60.8 kB 802.0 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#     --------------------------------------- 0.2/10.9 MB 4.8 MB/s eta 0:00:03
#    - -------------------------------------- 0.3/10.9 MB 3.8 MB/s eta 0:00:03
#    - -------------------------------------- 0.3/10.9 MB 3.5 MB/s eta 0:00:04
#    -- ------------------------------------- 0.6/10.9 MB 3.6 MB/s eta 0:00:03
#    --- ------------------------------------ 0.9/10.9 MB 3.9 MB/s eta 0:00:03
#    --- ------------------------------------ 1.1/10.9 MB 4.0 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.3/10.9 MB 4.0 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.3/10.9 MB 4.0 MB/s eta 0:00:03
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
data= pd.read_csv ("C:\\Users\\LENOVO\\Downloads\\Airline_customer_satisfaction.csv")

# %%
# Summary
print(df.describe())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Summary
# ----> 2 print(df.describe())
#
# NameError: name 'df' is not defined

# %%
file_path = ("C:\\Users\\LENOVO\\Downloads\\Airline_customer_satisfaction.csv")
df = pd.read_csv(file_path)

# %%
# Summary
print(df.describe())
# Out:
#                  Age  Flight Distance   Seat comfort  \
# count  129880.000000    129880.000000  129880.000000
# mean       39.427957      1981.409055       2.838597
# std        15.119360      1027.115606       1.392983
# min         7.000000        50.000000       0.000000
# 25%        27.000000      1359.000000       2.000000
# 50%        40.000000      1925.000000       3.000000
# 75%        51.000000      2544.000000       4.000000
# max        85.000000      6951.000000       5.000000
#
#        Departure/Arrival time convenient  Food and drink  Gate location  \
# count                      129880.000000   129880.000000  129880.000000
# mean                            2.990645        2.851994       2.990422
# std                             1.527224        1.443729       1.305970
# min                             0.000000        0.000000       0.000000
# 25%                             2.000000        2.000000       2.000000
# ...

# %%
# Plot missing values
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 # Plot missing values
# ----> 2 sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
#       3 plt.title('Missing Values Heatmap')
#       4 plt.show()
#
# NameError: name 'sns' is not defined

# %%
# Sum of missing values
print(df.isnull().sum())

# Head and Tail of the DataFrame
print(df.head())
print(df.tail())
# Out:
# satisfaction                           0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Seat comfort                           0
# Departure/Arrival time convenient      0
# Food and drink                         0
# Gate location                          0
# Inflight wifi service                  0
# Inflight entertainment                 0
# Online support                         0
# Ease of Online booking                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Cleanliness                            0
# Online boarding                        0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# dtype: int64
# ...

# %%
# Column names
print(df.columns)
# Out:
# Index(['satisfaction', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Seat comfort', 'Departure/Arrival time convenient',
#        'Food and drink', 'Gate location', 'Inflight wifi service',
#        'Inflight entertainment', 'Online support', 'Ease of Online booking',
#        'On-board service', 'Leg room service', 'Baggage handling',
#        'Checkin service', 'Cleanliness', 'Online boarding',
#        'Departure Delay in Minutes', 'Arrival Delay in Minutes'],
#       dtype='object')

# %%
# Data types
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   satisfaction                       129880 non-null  object
#  1   Customer Type                      129880 non-null  object
#  2   Age                                129880 non-null  int64
#  3   Type of Travel                     129880 non-null  object
#  4   Class                              129880 non-null  object
#  5   Flight Distance                    129880 non-null  int64
#  6   Seat comfort                       129880 non-null  int64
#  7   Departure/Arrival time convenient  129880 non-null  int64
#  8   Food and drink                     129880 non-null  int64
#  9   Gate location                      129880 non-null  int64
#  10  Inflight wifi service              129880 non-null  int64
# ...

# %%
# Replace missing values with the mean for numeric columns
numeric_cols = df.select_dtypes(include=[np.number]).columns
imputer = SimpleImputer(strategy='mean')
df[numeric_cols] = imputer.fit_transform(df[numeric_cols])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 # Replace missing values with the mean for numeric columns
# ----> 2 numeric_cols = df.select_dtypes(include=[np.number]).columns
#       3 imputer = SimpleImputer(strategy='mean')
#       4 df[numeric_cols] = imputer.fit_transform(df[numeric_cols])
#
# NameError: name 'np' is not defined

# %%
# Correlation matrix
cor_matrix = df.corr()
print(cor_matrix)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 # Correlation matrix
# ----> 2 cor_matrix = df.corr()
#       3 print(cor_matrix)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
# ...

# %%
# Boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['flight_distance', 'seat_comfort', 'departure', 'foodanddrink', 'onlinesupport', 'inflightentertainment', 'baggagehandling']])
plt.title('Boxplot of Features')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 # Boxplot
# ----> 2 plt.figure(figsize=(10, 6))
#       3 sns.boxplot(data=df[['flight_distance', 'seat_comfort', 'departure', 'foodanddrink', 'onlinesupport', 'inflightentertainment', 'baggagehandling']])
#       4 plt.title('Boxplot of Features')
#
# NameError: name 'plt' is not defined

# %%
# Boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['flight_distance', 'seat_comfort', 'departure', 'foodanddrink', 'onlinesupport', 'inflightentertainment', 'baggagehandling']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 # Boxplot
# ----> 2 plt.figure(figsize=(10, 6))
#       3 sns.boxplot(data=df[['flight_distance', 'seat_comfort', 'departure', 'foodanddrink', 'onlinesupport', 'inflightentertainment', 'baggagehandling']])
#
# NameError: name 'plt' is not defined

# %%
# Boxplot

sns.boxplot(data=df[['flight_distance', 'seat_comfort', 'departure', 'foodanddrink', 'onlinesupport', 'inflightentertainment', 'baggagehandling']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 3
#       1 # Boxplot
# ----> 3 sns.boxplot(data=df[['flight_distance', 'seat_comfort', 'departure', 'foodanddrink', 'onlinesupport', 'inflightentertainment', 'baggagehandling']])
#
# NameError: name 'sns' is not defined

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 # Split the data into training and testing sets
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)
#
# NameError: name 'X' is not defined

# %%
# Assuming 'satisfaction' is the target variable and the rest are features
# Replace 'satisfaction' with the correct column name in your dataset
X = df.drop('satisfaction', axis=1)
y = df['satisfaction']

# Convert categorical variables to dummy/indicator variables
X = pd.get_dummies(X, drop_first=True)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)

# %%
# Logistic Regression Model
log_reg = LogisticRegression(max_iter=1000)
log_reg.fit(X_train, y_train)
predicted_probs = log_reg.predict_proba(X_test)[:, 1]
predicted_class = (predicted_probs >= 0.5).astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 # Logistic Regression Model
# ----> 2 log_reg = LogisticRegression(max_iter=1000)
#       3 log_reg.fit(X_train, y_train)
#       4 predicted_probs = log_reg.predict_proba(X_test)[:, 1]
#
# NameError: name 'LogisticRegression' is not defined

# %%
pip install logistic regression
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement logistic (from versions: none)
# ERROR: No matching distribution found for logistic
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Confusion Matrix
CM = confusion_matrix(y_test, predicted_class)
ConfusionMatrixDisplay(confusion_matrix=CM).plot()
plt.title('Logistic Regression Confusion Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 # Confusion Matrix
# ----> 2 CM = confusion_matrix(y_test, predicted_class)
#       3 ConfusionMatrixDisplay(confusion_matrix=CM).plot()
#       4 plt.title('Logistic Regression Confusion Matrix')
#
# NameError: name 'confusion_matrix' is not defined

# %%
pip install pandas numpy matplotlib seaborn scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
 python.exe -m pip install
# Out:
#   Cell In[42], line 1
#     python.exe -m pip install
#                   ^
# SyntaxError: invalid syntax

# %%
# ROC and AUC
fpr, tpr, _ = roc_curve(y_test, predicted_probs)
roc_auc = auc(fpr, tpr)
print(f"AUC-ROC for Logistic Regression: {roc_auc}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 2
#       1 # ROC and AUC
# ----> 2 fpr, tpr, _ = roc_curve(y_test, predicted_probs)
#       3 roc_auc = auc(fpr, tpr)
#       4 print(f"AUC-ROC for Logistic Regression: {roc_auc}")
#
# NameError: name 'roc_curve' is not defined

# %%
cor_matrix= df.corr()
print(cor_matrix)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 cor_matrix= df.corr()
#       2 print(cor_matrix)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
# ...

# %%
# Heatmap of the correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(cor_matrix, annot=True, cmap='coolwarm')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 2
#       1 # Heatmap of the correlation matrix
# ----> 2 plt.figure(figsize=(12, 10))
#       3 sns.heatmap(cor_matrix, annot=True, cmap='coolwarm')
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
pip install matplotlib.pyplot
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
